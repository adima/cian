# %%
url = "http://www.cian.ru/cat.php?deal_type=sale&engine_version=2&maxtarea=50&mintarea=30&offer_type=flat&p=2&region=1"

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
resp = requests.get(url).text

# %%
resp
# Out:
# u'\n<!DOCTYPE html>\n<html class="no-touch" >\n    <head>\n        \n\n<!-- Google Analytics Content Experiment code -->\n<script>function utmx_section(){}function utmx(){}(function(){var\nk=\'57940811-35\',d=document,l=d.location,c=d.cookie;\nif(l.search.indexOf(\'utm_expid=\'+k)>0)return;\nfunction f(n){if(c){var i=c.indexOf(n+\'=\');if(i>-1){var j=c.\nindexOf(\';\',i);return escape(c.substring(i+n.length+1,j<0?c.\nlength:j))}}}var x=f(\'__utmx\'),xx=f(\'__utmxx\'),h=l.hash;d.write(\n\'<sc\'+\'ript src="\'+\'http\'+(l.protocol==\'https:\'?\'s://ssl\':\n\'://www\')+\'.google-analytics.com/ga_exp.js?\'+\'utmxkey=\'+k+\n\'&utmx=\'+(x?x:\'\')+\'&utmxx=\'+(xx?xx:\'\')+\'&utmxtime=\'+new Date().\nvalueOf()+(h?\'&utmxhash=\'+escape(h.substr(1)):\'\')+\n\'" type="text/javascript" charset="utf-8"><\\/sc\'+\'ript>\')})();\n</script><script>utmx(\'url\',\'A/B\');</script>\n<!-- End of Google Analytics Content Experiment code -->\n\n\n        \n            <meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>\n            <meta name="google-site-verification" content="Eig23WXwvPZu3gp9EYVreR61rG4TX1bHQDEG0Di5ZSE"/>\n            <meta name="apple-mobile-web-app-title" content="\u0426\u0418\u0410\u041d">\n        \n\n        \n            <meta property="og:type" content="website"/>\n            <meta property="og:site_name" content="CIAN"/>\n            \n            \n            \n                <meta property="og:image" content="http://www.cian.ru/static/images/cian-logo-cyrillic-vertical.png" />\n            \n            \n        \n\n        \n            <title>\n                \u041a\u0443\u043f\u0438\u0442\u044c \u043a\u0432\u0430\u0440\u0442\u0438\u0440\u0443 \u2014 39197 \u043e\u0431\u044a\u044f\u0432\u043b\u0435\u043d\u0438\u0439\n            </title>\n            \n                \n                    <meta name="description" content="\u041f\u0440\u043e\u0434\u0430\u0436\u0430 \u043a\u0432\u0430\u0440\u0442\u0438\u0440 \u2014 39197 \u043e\u0431\u044a\u044f\u0432\u043b\u0435\u043d\u0438\u0439" />\n                \n            \n            \n                \n            \n            \n            \n                <meta name="robots" content="noindex" />\n            \n        \n\n        <link rel="icon" href="/static/images/favicon.ico" type="image/x-icon"/>\n\n        \n    \n            <!--[if lte IE 10]>\n            <link rel="stylesheet" type="text/css" href="/static/fonts/webfont_ie.css" media="all"/>\n            <![endif]-->\n            \n            <link rel="stylesheet" type="text/css" href="/static/stylesheets/common.css?123" media="all"/>\n            \n            <link rel="stylesheet" type="text/css" href="/static/stylesheets/objects.css?201201333323238737" media="all"/>\n            <link rel="stylesheet" type="text/css" href="/static/stylesheets/object_descr.css?12474290123" media="all"/>\n            <link rel="stylesheet" type="text/css" href="/static/stylesheets/note.css" media="all"/>\n            <link rel="stylesheet" type="text/css" href="/static/stylesheets/form.css" media="all"/>\n            <link rel="stylesheet" type="text/css" href="/static/stylesheets/popups.css" media="all"/>\n            <link rel="stylesheet" type="text/css" href="/static/stylesheets/tab_buttons.css" media="all"/>\n            <link rel="stylesheet" type="text/css" href="/static/stylesheets/gallery.css" media="all"/>\n            <link rel="stylesheet" type="text/css" href="/static/stylesheets/print.css?v=81" media="all"/>\n            <link rel="stylesheet" type="text/css" href="/static/stylesheets/notifications.css" media="all"/>\n            <link rel="stylesheet" type="text/css" href="/static/stylesheets/jtour.css" media="all"/>\n            <link rel="stylesheet" type="text/css" href="/static/stylesheets/retina.css" media="all"/>\n            <link rel="stylesheet" type="text/css" href="/static/global/styles/global.css?v=b1" media="all"/>\n            <link rel="stylesheet" type="text/css" href=" ...

# %%
soup = BeautifulSoup(resp, 'html.parser')

# %%
from lxml.html import parse

# %%
parsed = parse(urlopen(url))

# %%
from urllib2 import urlopen

# %%
parsed

# %%
doc = parsed.getroot()

# %%
print doc.findall('.//a')[89].text
# Out:
# пос. Щапово

# %%
doc.findall('.//table')[2].text
# Out:
# '\n                        '

# %%
parsed.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-f4748055186a> in <module>()
# ----> 1 parsed.text
#
# AttributeError: 'lxml.etree._ElementTree' object has no attribute 'text'

# %%
doc.findall('.//table').
# Out:
# [<Element table at 0x7f5265f13ec0>,
#  <Element table at 0x7f5265f13f18>,
#  <Element table at 0x7f5265f13f70>,
#  <Element table at 0x7f5265f13fc8>]

# %%
pa
# Out:
# '\n                    '

# %%
urlopen(url)
# Out:
# <addinfourl at 139991874197048 whose fp = <socket._fileobject object at 0x7f5265ee2350>>
